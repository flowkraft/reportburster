# %% [markdown]
# # 🦉 Chat with Athena
#
# Ask questions about your databases in **plain English**.
# Athena generates the SQL, runs it, and explains the results.
#
# **Run the cell below to start chatting** (Shift+Enter).

# %%
from chat2db import Chat2DB
Chat2DB().interactive()
